# %% [markdown]
# #Quiz 1: Sofía Ayala
# 1.- Crea un diccionario que contenga 3 llaves que sean de tipo string y cuyos valores sean una lista que contenga 5 valores (3 numéricos y 2 flotantes).
#
# 2.- A partir del diccionario anterior, muestra a sus ítems. ¿Qué tipo de objeto se obtiene?
#
# 3.- Crea un panel de datos usando tu diccionario. Realiza tres segregaciones distintas.
#
# 4.- Realiza un breve análisis descriptivo de tu panel de datos. Explica los valores que obtienes.
#
# 5.- Realiza dos filtros de búsqueda sobre tu panel de datos.

# %%
#Ejercicio 1
finanzas={"Antonio":[9.5,1.76,20,1,3],
        "Alejandra":[9.2,1.60,21,1,11],
        "Manuel":[9.2,1.77,21,1,8]}

# %%
print(finanzas)
# Out:
# {'Antonio': [9.5, 1.76, 20, 1, 3], 'Alejandra': [9.2, 1.6, 21, 1, 11], 'Manuel': [9.2, 1.77, 21, 1, 8]}

# %%
#Ejercicio 2
type(finanzas)
# Out:
# dict

# %%
#Ejercicio 3
import pandas as pd
Alumnos = pd.DataFrame(finanzas,
                       index= ["Promedio", "Estatura", "Edad", "Número de hermanos","Número de primos"])
Alumnos
# Out:
#                     Antonio  Alejandra  Manuel
# Promedio               9.50        9.2    9.20
# Estatura               1.76        1.6    1.77
# Edad                  20.00       21.0   21.00
# Número de hermanos     1.00        1.0    1.00
# Número de primos       3.00       11.0    8.00

# %%
#Recortar la tabla 3 veces
Alumnos.iloc[0] #Solo que me de los promedios
# Out:
# Antonio      9.5
# Alejandra    9.2
# Manuel       9.2
# Name: Promedio, dtype: float64

# %%
Alumnos[["Antonio","Manuel"]]#Solo quiero a los alumnos Antonio y Manuel
# Out:
#                     Antonio  Manuel
# Promedio               9.50    9.20
# Estatura               1.76    1.77
# Edad                  20.00   21.00
# Número de hermanos     1.00    1.00
# Número de primos       3.00    8.00

# %%
Alumnos.iloc[0:2] #Solo quiero que me de peomedios y estatura de los alumnos
# Out:
#           Antonio  Alejandra  Manuel
# Promedio     9.50        9.2    9.20
# Estatura     1.76        1.6    1.77

# %%
#Ejercicio 4: Tabla de estadística
Alumnos.describe()
#mean: media
#std: desviación estandar
#min: valor más chico
#max: valor mas grande
#25%(Primer cuartil), 50%(Mediana), 75%(Tercer cuartil) "Caja de bigotes"
# Out:
#          Antonio  Alejandra     Manuel
# count   5.000000   5.000000   5.000000
# mean    7.052000   8.760000   8.194000
# std     7.979569   8.162598   8.032196
# min     1.000000   1.000000   1.000000
# 25%     1.760000   1.600000   1.770000
# 50%     3.000000   9.200000   8.000000
# 75%     9.500000  11.000000   9.200000
# max    20.000000  21.000000  21.000000

# %%
#Ejercicio 5: Dos filtros de búsqueda sobre tu panel de datos
Alumnos.mean(axis=1) #te saca el promedio por columnas
# Out:
# Promedio               9.300000
# Estatura               1.710000
# Edad                  20.666667
# Número de hermanos     1.000000
# Número de primos       7.333333
# dtype: float64

# %%
Alumnos.min()
# Out:
# Antonio      1.0
# Alejandra    1.0
# Manuel       1.0
# dtype: float64
