# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
d=pd.read_csv("/content/drive/MyDrive/POO/ETF prices.csv")

# %%
d  #renglones "para abajo" axis=0 / columnas "para la derecha" axis=1
# Out:
#         fund_symbol  price_date   open   high    low  close  adj_close  volume
# 0               AAA  2020-09-09  25.10  25.12  25.07  25.07      24.85   17300
# 1               AAA  2020-09-10  25.06  25.07  25.05  25.07      24.85   23500
# 2               AAA  2020-09-11  25.04  25.05  25.02  25.03      24.81   33400
# 3               AAA  2020-09-14  25.01  25.06  25.01  25.02      24.80   13100
# 4               AAA  2020-09-15  25.02  25.03  25.01  25.01      24.79   12100
# ...             ...         ...    ...    ...    ...    ...        ...     ...
# 3866025         ZSL  2021-11-23  26.81  27.21  26.30  26.35      26.35  190900
# 3866026         ZSL  2021-11-24  26.79  26.96  26.57  26.69      26.69  109000
# 3866027         ZSL  2021-11-26  26.67  28.14  26.67  27.72      27.72  205500
# 3866028         ZSL  2021-11-29  27.89  28.56  27.80  28.27      28.27  411900
# 3866029         ZSL  2021-11-30  28.15  28.73  25.91  28.49      28.49  219400
#
# ...

# %%
d.shape #nos da la dimensión de la matriz
# Out:
# (3866030, 8)

# %%
d.ndim #nos da la dimensión como objeto de phyton
# Out:
# 2

# %%
d= d.drop(columns=['fund_symbol']) #Se deshace de las columnas que le pidas

# %%
d= d.iloc[0:100] #Seleccionar por renglones

# %%
d.iloc[:,[1,2,5]] #Seleccionar columnas en las posiciones 1,2 y 5 (Tomando en cuenta que la primera columna es 0)
# Out:
#      open   high  adj_close
# 0   25.10  25.12      24.85
# 1   25.06  25.07      24.85
# 2   25.04  25.05      24.81
# 3   25.01  25.06      24.80
# 4   25.02  25.03      24.79
# ..    ...    ...        ...
# 95  25.16  25.17      25.02
# 96  25.14  25.15      25.01
# 97  25.15  25.15      25.01
# 98  25.16  25.16      25.00
# 99  25.14  25.14      25.01
#
# [100 rows x 3 columns]

# %%
d["close"].value_counts()# "Tabla de frecuencias"
# Out:
# 25.07    10
# 24.95     7
# 24.91     7
# 25.15     6
# 25.08     6
# 24.98     6
# 25.06     6
# 25.05     5
# 25.03     5
# 24.90     4
# 25.09     4
# 25.04     4
# 24.89     4
# 24.92     4
# 24.93     3
# 24.94     3
# 25.01     3
# 25.10     2
# 25.16     2
# 24.87     1
# 25.00     1
# 24.96     1
# 24.99     1
# 24.97     1
# 25.12     1
# 25.02     1
# 25.17     1
# 25.13     1
# Name: close, dtype: int64

# %%
d.describe()#te da datos estadísticos descriptivos
#mean: media
#std: desviación estandar
#min: valor más chico
#max: valor mas grande
#25%(Primer cuartil), 50%(Mediana), 75%(Tercer cuartil) "Caja de bigotes"
# Out:
#              open        high         low       close   adj_close  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000
# mean    25.015900   25.021800   25.011400   25.014900   24.835500
# std      0.081353    0.080106    0.081415    0.080735    0.104933
# min     24.870000   24.870000   24.870000   24.870000   24.690000
# 25%     24.940000   24.950000   24.940000   24.940000   24.740000
# 50%     25.030000   25.040000   25.025000   25.030000   24.850000
# 75%     25.070000   25.080000   25.070000   25.070000   24.930000
# max     25.160000   25.170000   25.160000   25.170000   25.020000
#
#               volume
# count     100.000000
# mean     5404.000000
# std     12979.470348
# min         0.000000
# 25%       500.000000
# 50%      1800.000000
# 75%      4500.000000
# max    115400.000000

# %%
d.mean(axis=1) #te saca el promedio por columnas porque le pusimos axis=1, si quisieramos el promedio por renglones pondriamos axis=0
# Out:
# <ipython-input-78-6f061eda9618>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   d.mean(axis=1) #te saca el promedio por columnas porque le pusimos axis=1, si quisieramos el promedio por renglones pondriamos axis=0
# 0     2904.201667
# 1     3937.516667
# 2     5587.491667
# 3     2204.150000
# 4     2037.476667
#          ...
# 95     104.280000
# 96     104.265000
# 97      54.268333
# 98     537.603333
# 99     237.591667
# Length: 100, dtype: float64

# %%
import numpy as np
precios=np.random.rand(10)
closed=np.random.randint(1,100,10)

# %%
len(precios)
# Out:
# 10

# %%
closed
# Out:
# array([63, 57, 67, 18, 88, 94, 21, 10, 25, 89])

# %%
diccionario={"Precios": precios,
             "Cierre": closed}
import pandas as pd
precio = pd.DataFrame(diccionario)
precio
# Out:
#     Precios  Cierre
# 0  0.442216      63
# 1  0.942870      57
# 2  0.104430      67
# 3  0.411331      18
# 4  0.946800      88
# 5  0.835209      94
# 6  0.278866      21
# 7  0.750374      10
# 8  0.694195      25
# 9  0.857864      89

# %%
precio[precio["Cierre"]>20]
# Out:
#     Precios  Cierre
# 0  0.442216      63
# 1  0.942870      57
# 2  0.104430      67
# 4  0.946800      88
# 5  0.835209      94
# 6  0.278866      21
# 8  0.694195      25
# 9  0.857864      89
