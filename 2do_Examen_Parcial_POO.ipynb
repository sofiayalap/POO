# %% [markdown]
# ## Examen
# ##Sofía Ayala Pichardo
#
# * Es necesario seguir los lineamientos ya preestablecidos.
#
# * Habrá cero tolerancia al plagio.
#
# * Sólo podrás hacer uso de las libretas que tengas, no se permite el uso de ChatGPT.
#
# * Todas las soluciones deben presentarse de manera lógica. Se penalizará la ausencia de argumentos y de documentación.

# %% [markdown]
# **Ejercicio 1:**
#
# ##¿Qué es una clase y por qué es útil? \\
# ###Una clase es un conjunto de funciones y son útiles porque nos permiten organizar y estructurar el código, tambien nos permite que una clase herede atributos y métodos de otras. Otro ejemplo de porque son útiles es porque nos permite agrupar datos y comportamientos relacionados en un solo objeto.
#
# ##Define una clase con un ejemplo, dando todas sus características.
#
# ###Ejemplo: La clase es el nombre del país (México) y sus características serían el idioma, capital y continente de ese mismo.
# ---

# %%
class Mexico():
  def __init__(self, capital, idioma, continente):
    self.capital = capital
    self.idioma = idioma
    self.continente = continente

def MexicoId(self):
    print ("En Mexico se habla español")

def MexicoCap(self):
    print ("La capital de Mexico es la Ciudad de México")

def MexicoCont(self):
    print ("Mexico esta en America")

var1= MexicoCap("CDMX")
# Out:
# La capital de Mexico es la Ciudad de México

# %% [markdown]
# **Ejercicio 2:**
#
# En Python, un **constructor** es un método especial que se llama automáticamente cuando se crea un objeto. Se utiliza para inicializar los atributos del objeto y realizar cualquier tarea de configuración necesaria antes de su uso. \\
#
# Para este ejercicio contesta las siguientes preguntas:
#
#
# 1.   ¿Cuál es la sintaxis para definir un constructor dentro de una clase?
# ###Para definir un constructor debes utilizar el método llamado "init"
# 2.   Considera el siguiente código: \\
#
# ![constructor.png](data:image/png;base64,...)
#
# \\
# La clase 'Human' tiene un constructor que toma dos parametros, ¿cuáles son?
# ###Los parámetros son legs y arms y toman como valor al 2

# %% [markdown]
# 3. Crea dos atributos (definiciones y polimorfismos) asociados a la clase 'Human´.
#
# ---

# %%
class Human():

    def __init__(self,name,age):
        self.name = name
        self.age = age

    def presentarse(self, presentarse):
        print(f"{self.name}) dice:{presentarse}")

    def edad(self):
        return self.age

# %%
Sofia=Human("Sofia",21)
print(f"{Sofia.name} tiene {Sofia.edad()} y es humana")
# Out:
# Sofia tiene 21 y es humana

# %% [markdown]
# **Ejercicio 3:**
#
# Indica si las siguientes afirmaciones son verdaderas o falsas:
#
#
#
# *   El primer parámetro del método '__ init() __' es siempre 'self' , que se refiere a la instancia de la clase que se está creando. Se pasa automáticamente al constructor cuando se instancia el objeto.
# ###verdadero
# *   Después de 'self', puedes definir cualquier otro parámetro necesario para inicializar los atributos del objeto.
# ###verdadero
# *   Cuando añades la función '__ init ()  __' , la clase heredada ya no hereda la función ' __ init () __ ' de la clase madre.
# ###falso porque cuando pones la función init, la clase heredada no cancela la función init de la Clase Madre, solo se cancela si declaras una función init en la Subclase.
# *   En la programación orientada a objetos, las clases pueden heredar atributos y métodos de otras clases.
# ###verdadero
# *  Cuando hablamos de polimorfismos en Python, diferentes clases pueden ser tratadas como instancias de la misma superclase, independientemente de cómo implementen el mismo método.
# ###verdadero
#
# ---

# %% [markdown]
# **Ejercicio 4:** A partir de un diccionario, crea un DataFrame (que llamarás **precios_muestra**) que consista de dos columnas y que tenga 12 valores **flotantes** que eligirás de manera aleatoria en el intervalo (8,13). Etiqueta del 1 al 12 y llama a la columna de etiquetas Mes.
#
# 1.- Construye una función que calcule los rendimientos simples de cada columna.
#
# 2.- Las desviaciones estadísticas de los rendimientos ayudan a calcular la volatilidad del portafolio:
# $$\text{desviaciones}=(\text{rendimientos}-\text{media}(\text{rendimientos}))^2.$$
# Crea una función que calcule la media de las desviaciones y luego la volatilidad de tu portafolio (raíz cuadrada de la media de las desviaciones).
#
# 3.- Anualizamos la volatilidad escalándola (multiplicándola) por la raíz cuadrada del número de períodos por observación.
#
# Por lo tanto, para anualizar la volatilidad de una serie mensual, la multiplicamos por la raíz cuadrada de 12. Muestra la serie de la volatilidad anualizada.
#
# 4.- Realiza una gráfica de barras para los rendimientos y una gráfica en líneas para los precios.
#
# 5.- Calcula los rendimientos compuestos para cada columna y después anualiza los rendimientos.
#
# ---

# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
valores_aleatorios= [random.uniform(8,13) for _ in range(12)]
data={"Mes":list(range(1,13)),"Precio":valores_aleatorios}
precios_muestra = pd.DataFrame(data)
print (precios_muestra)
# Out:
#     Mes     Precio
# 0     1  11.749245
# 1     2   8.641661
# 2     3  11.638410
# 3     4   9.433623
# 4     5  11.229388
# 5     6   8.171835
# 6     7   8.633047
# 7     8  10.726533
# 8     9  12.918541
# 9    10   9.099778
# 10   11  10.868486
# 11   12  10.219381

# %%
#1. Redimientos simples de cada columna
def rendimientos_simples(df):
    df["Rendimiento"] = df["Precio"].pct_change()
    return df

precios_muestra = rendimientos_simples(precios_muestra)
rendimientos_simples(precios_muestra)
# Out:
#     Mes     Precio  Rendimiento
# 0     1  11.749245          NaN
# 1     2   8.641661    -0.264492
# 2     3  11.638410     0.346779
# 3     4   9.433623    -0.189441
# 4     5  11.229388     0.190358
# 5     6   8.171835    -0.272281
# 6     7   8.633047     0.056439
# 7     8  10.726533     0.242497
# 8     9  12.918541     0.204354
# 9    10   9.099778    -0.295603
# 10   11  10.868486     0.194368
# 11   12  10.219381    -0.059724

# %%
#2. Media de las desviaciones y luego la volatilidad del portafolio
rendimientos_simples(precios_muestra)["Rendimiento"].std()
# Out:
# 0.23807887618758125

# %%
#3. Serie de volatilidad anualizada
rendimientos_simples(precios_muestra)["Rendimiento"].std()**12
# Out:
# 3.316273696444671e-08

# %%
#4. Gráfica de barras para los rendimientos

plt.bar(precios_muestra["Mes"], precios_muestra["Rendimiento"])
# Out:
# <BarContainer object of 12 artists>

# %%
#4. Gráfica en línea para los precios
plt.plot(precios_muestra["Mes"], precios_muestra["Precio"])

# %%
#5. Rendimientos compuestos para cada columna y anualizarlos
def rendimientos_compuestos(df):
    df["Rendimiento_Compuesto"] = (1 + df["Rendimiento"]).cumprod() - 1
    return df

precios_muestra = rendimientos_compuestos(precios_muestra)
rendimientos_compuestos(precios_muestra)
# Out:
#     Mes     Precio  Rendimiento  Rendimiento_Compuesto
# 0     1  11.749245          NaN                    NaN
# 1     2   8.641661    -0.264492              -0.264492
# 2     3  11.638410     0.346779              -0.009433
# 3     4   9.433623    -0.189441              -0.197087
# 4     5  11.229388     0.190358              -0.044246
# 5     6   8.171835    -0.272281              -0.304480
# 6     7   8.633047     0.056439              -0.265225
# 7     8  10.726533     0.242497              -0.087045
# 8     9  12.918541     0.204354               0.099521
# 9    10   9.099778    -0.295603              -0.225501
# 10   11  10.868486     0.194368              -0.074963
# 11   12  10.219381    -0.059724              -0.130210

# %%
rendimientos_anuales=rendimientos_compuestos(precios_muestra)["Rendimiento_Compuesto"].mean()**252
rendimientos_anuales
# Out:
# 1.494333150734532e-218

# %% [markdown]
# **Ejercicio 5:** Carga dos tickers y realiza los pasos del ejercicio anterior usando los tickers que elijas. Recuerda tomar en cuenta la ventana de tiempo que manejarás. Realiza un análisis estadístico (estadística descriptiva, histogramas y gráficas de series de tiempo).

# %%
import yfinance as yf

# %%
#Dos tickers
tickers= (["AMZN", "MSFT"])
fecha_inicial="2020-01-01"
fecha_final="2023-01-01"

# %%
datos= yf.download(tickers, fecha_inicial, fecha_final) ["Close"]
datos
# Out:
# [*********************100%%**********************]  2 of 2 completed
#                  AMZN        MSFT
# Date
# 2020-01-02  94.900497  160.619995
# 2020-01-03  93.748497  158.619995
# 2020-01-06  95.143997  159.029999
# 2020-01-07  95.343002  157.580002
# 2020-01-08  94.598503  160.089996
# ...               ...         ...
# 2022-12-23  85.250000  238.729996
# 2022-12-27  83.040001  236.960007
# 2022-12-28  81.820000  234.529999
# 2022-12-29  84.180000  241.009995
# 2022-12-30  84.000000  239.820007
#
# [756 rows x 2 columns]

# %%
datos.describe()
# Out:
#              AMZN        MSFT
# count  756.000000  756.000000
# mean   142.455482  245.860939
# std     27.856019   47.582265
# min     81.820000  135.419998
# 25%    118.337875  212.474998
# 50%    154.467499  245.144997
# 75%    164.633247  283.737495
# max    186.570496  343.109985

# %%
returns=datos.pct_change()
returns
# Out:
#                 AMZN      MSFT
# Date
# 2020-01-02       NaN       NaN
# 2020-01-03 -0.012139 -0.012452
# 2020-01-06  0.014886  0.002585
# 2020-01-07  0.002092 -0.009118
# 2020-01-08 -0.007809  0.015928
# ...              ...       ...
# 2022-12-23  0.017425  0.002267
# 2022-12-27 -0.025924 -0.007414
# 2022-12-28 -0.014692 -0.010255
# 2022-12-29  0.028844  0.027630
# 2022-12-30 -0.002138 -0.004938
#
# [756 rows x 2 columns]

# %%
returns.std() #Desvuiación estandar
# Out:
# AMZN    0.024621
# MSFT    0.021904
# dtype: float64

# %%
returns.var() #Varianza
# Out:
# AMZN    0.000606
# MSFT    0.000480
# dtype: float64

# %%
returns.mean() #Media
# Out:
# AMZN    0.000141
# MSFT    0.000771
# dtype: float64

# %%
#Volatilidad
(1+returns.mean())**252-1
# Out:
# AMZN    0.036196
# MSFT    0.214352
# dtype: float64

# %%
#Histograma
returns.hist()
# Out:
# array([[<Axes: title={'center': 'AMZN'}>,
#         <Axes: title={'center': 'MSFT'}>]], dtype=object)

# %%
#Serie de tiempo
returns.plot()
# Out:
# <Axes: xlabel='Date'>
